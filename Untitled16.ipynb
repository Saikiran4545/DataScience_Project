# %% [markdown]
# <a href="https://colab.research.google.com/github/Saikiran4545/DataScience_Project/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import ccxt
import time

class TradingBot:
    def __init__(self, initial_budget, symbol, api_key, api_secret, api_passphrase):
        self.budget = initial_budget
        self.symbol = symbol
        self.api_key = api_key
        self.api_secret = api_secret
        self.api_passphrase = api_passphrase
        self.exchange = ccxt.kucoin({
            'apiKey': api_key,
            'secret': api_secret,
            'password': api_passphrase,
        })

    def place_order(self, order_type, price, quantity):
        try:
            order = None
            if order_type.lower() == "buy":
                order = self.exchange.create_limit_buy_order(self.symbol, quantity, price)
            elif order_type.lower() == "sell":
                order = self.exchange.create_limit_sell_order(self.symbol, quantity, price)

            order_id = order['id'] if order else None
            print(f"{order_type} order placed - Order ID: {order_id}")
            return order_id
        except Exception as e:
            print(f"Error during order placement: {e}")
            return None

    def execute_strategy(self):
        try:
            ticker = self.exchange.fetch_ticker(self.symbol)
            current_price = ticker['ask']

            if current_price < 50000 and self.budget > 0:
                # Place a buy order
                buy_price = current_price  # Buy below 0.1%
                buy_quantity = min(self.budget / buy_price, 1.0)
                buy_order_id = self.place_order("buy", buy_price, buy_quantity)

                if buy_order_id:
                    self.budget -= buy_price * buy_quantity
                    print(f"Budget after buying: {self.budget:.2f}")

                    # Wait for the buy order to complete before placing a sell order
                    self.wait_for_order_execution(buy_order_id)

                    # Place a corresponding sell order with a profit target of 0.1%
                    sell_price = buy_price * 1.001
                    sell_quantity = buy_quantity
                    sell_order_id = self.place_order("sell", sell_price, sell_quantity)

                    if sell_order_id:
                        print("Sell order placed.")
                        return sell_order_id

        except Exception as e:
            print(f"Error in executing strategy: {e}")

        return None

    def wait_for_order_execution(self, order_id):
        print("Waiting for the last order to execute...")
        while True:
            try:
                order_status = self.exchange.fetch_order(order_id)
                if order_status['status'] == 'closed':
                    print("Last order executed.")
                    return True
                time.sleep(10)
            except Exception as e:
                print(f"Error checking last order: {e}")

    def run(self):
        sell_order_id = self.execute_strategy()

        if sell_order_id:
            # Wait for the last sell order to execute
            self.wait_for_order_execution(sell_order_id)
            print("Bot will stop.")


if __name__ == "__main__":
    initial_budget = 10
    symbol = 'SOL/USDT'
    api_key = '657d43f44d8dba0001eb4c47'
    api_secret = '8d32247d-3752-49f4-a76e-c69f71f20cf3'
    api_passphrase = 'Mahadev@4545'

    trading_bot = TradingBot(initial_budget, symbol, api_key, api_secret, api_passphrase)

    try:
        trading_bot.run()
    except KeyboardInterrupt:
        print("Exiting...")
